# %% [markdown]
# ###Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ### Data Ingestion

# %%
data_path = "/Workspace/Users/terrysenosi@gmail.com/DSTV-viewership-analysis-python/Data Source/user_profile.csv"
data_path1 = "/Workspace/Users/terrysenosi@gmail.com/DSTV-viewership-analysis-python/Data Source/viewership.csv"

# %%
df = pd.read_csv(data_path)
df1 = pd.read_csv(data_path1)

# %%
df.head(5)

# %%
df1.head(5)
